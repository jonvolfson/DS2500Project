# %% [markdown]
# ## Testing Jupyter and Visualizations

# %% [markdown]
# * Countries
# * Covid Impacts
# * Country codes
#      * SG.VAW.REAS.ZS, Women who believe a husband is justified in beating his wife (any of five reasons) (%)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
filepath = "owid-covid-data.csv"

# %%
df = pd.read_csv(filepath)
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0        1803.987              NaN                597.029
# 1        1803.987              NaN                597.029
# 2        1803.987              NaN                597.029
# 3        1803.987              NaN                597.029
# 4        1803.987              NaN                597.029
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                 9.59             NaN           NaN                  37.746
# 1                 9.59             NaN           NaN                  37.746
# 2                 9.59             NaN           NaN                  37.746
# 3                 9.59             NaN           NaN                  37.746
# 4                 9.59             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
# [5 rows x 59 columns]

# %%
filepath2 = "world_dev_ind.csv"
pd.set_option("display.max.columns", None)
pd.set_option("display.precision", 2)

# %%
df2 = pd.read_csv(filepath2)
df2 = df2.rename(columns = {'2016 [YR2016]' : '2016', 
                            '2017 [YR2017]' : '2017',
                            '2018 [YR2018]' : '2018',
                            '2019 [YR2019]' : '2019',
                            '2020 [YR2020]' : '2020'})

df2 = df2.dropna()
df2.tail()
# Out:
#        Country Name Country Code  \
# 378835        World          WLD
# 378836        World          WLD
# 378837        World          WLD
# 378838        World          WLD
# 378839        World          WLD
#
#                                               Series Name        Series Code  \
# 378835  Women who believe a husband is justified in be...     SG.VAW.REFU.ZS
# 378836  Women who were first married by age 15 (% of w...  SP.M15.2024.FE.ZS
# 378837  Women who were first married by age 18 (% of w...  SP.M18.2024.FE.ZS
# 378838  Women's share of population ages 15+ living wi...  SH.DYN.AIDS.FE.ZS
# 378839  Young people (ages 15-24) newly infected with HIV     SH.HIV.INCD.YG
#
#           2016    2017    2018    2019 2020
# 378835      ..      ..      ..      ..   ..
# 378836      ..      ..      ..      ..   ..
# 378837      ..      ..      ..      ..   ..
# 378838    52.9      53      53      53   ..
# 378839  540000  510000  480000  460000   ..

# %%
df2['2016'] = pd.to_numeric(df2['2016'], errors='coerce')
df2['2017'] = pd.to_numeric(df2['2017'], errors='coerce')
df2['2018'] = pd.to_numeric(df2['2018'], errors='coerce')
df2['2019'] = pd.to_numeric(df2['2019'], errors='coerce')
df2['2020'] = pd.to_numeric(df2['2020'], errors='coerce')
df2 = df2.dropna(axis=1, how='all')

wivesdf = df2[
            (df2['Series Code'] == 'SG.VAW.REAS.ZS')]
wivesdf
# Out:
#                                       Country Name Country Code  \
# 1425                                   Afghanistan          AFG
# 2860                                       Albania          ALB
# 4295                                       Algeria          DZA
# 5730                                American Samoa          ASM
# 7165                                       Andorra          AND
# ...                                            ...          ...
# 373090                          Sub-Saharan Africa          SSF
# 374525  Sub-Saharan Africa (excluding high income)          SSA
# 375960   Sub-Saharan Africa (IDA & IBRD countries)          TSS
# 377395                         Upper middle income          UMC
# 378830                                       World          WLD
#
#                                               Series Name     Series Code  \
# 1425    Women who believe a husband is justified in be...  SG.VAW.REAS.ZS
# 2860    Women who believe a husband is justified in be...  SG.VAW.REAS.ZS
# 4295    Women who believe a husband is justified in be...  SG.VAW.REAS.ZS
# 5730    Women who believe a husband is justified in be...  SG.VAW.REAS.ZS
# 7165    Women who believe a husband is justified in be...  SG.VAW.REAS.ZS
# ...                                                   ...             ...
# 373090  Women who believe a husband is justified in be...  SG.VAW.REAS.ZS
# 374525  Women who believe a husband is justified in be...  SG.VAW.REAS.ZS
# 375960  Women who believe a husband is justified in be...  SG.VAW.REAS.ZS
# 377395  Women who believe a husband is justified in be...  SG.VAW.REAS.ZS
# 378830  Women who believe a husband is justified in be...  SG.VAW.REAS.ZS
#
#         2016  2017  2018  2019  2020
# 1425     NaN   NaN   NaN   NaN   NaN
# 2860     NaN   NaN   6.8   NaN   NaN
# 4295     NaN   NaN   NaN   NaN   NaN
# 5730     NaN   NaN   NaN   NaN   NaN
# 7165     NaN   NaN   NaN   NaN   NaN
# ...      ...   ...   ...   ...   ...
# 373090   NaN   NaN   NaN   NaN   NaN
# 374525   NaN   NaN   NaN   NaN   NaN
# 375960   NaN   NaN   NaN   NaN   NaN
# 377395   NaN   NaN   NaN   NaN   NaN
# 378830   NaN   NaN   NaN   NaN   NaN
#
# [264 rows x 9 columns]
