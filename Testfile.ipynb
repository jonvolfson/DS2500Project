# %% [markdown]
# ## Testing Jupyter and Visualizations

# %% [markdown]
# * Countries
# * Covid Impacts
# * Country codes
#      * SG.VAW.REAS.ZS, Women who believe a husband is justified in beating his wife (any of five reasons) (%)

# %%
import pandas as pd
import matplotlib import animation
import matplotlib.pyplot as plt

# %%
# reads in data from the given url and 
url = 'https://covid.ourworldindata.org/data/owid-covid-data.csv'

data = pd.read_csv(url)
data = data.dropna(subset=['continent'])
data['date'] = pd.to_datetime(data['date'], format = '%Y-%m-%d')
data = data.rename(columns={'location': 'name', 'iso_code': 'iso_a3'})
data.head()
# Out:
#   iso_a3 continent         name       date  total_cases  new_cases  \
# 0    AFG      Asia  Afghanistan 2020-02-24          1.0        1.0
# 1    AFG      Asia  Afghanistan 2020-02-25          1.0        0.0
# 2    AFG      Asia  Afghanistan 2020-02-26          1.0        0.0
# 3    AFG      Asia  Afghanistan 2020-02-27          1.0        0.0
# 4    AFG      Asia  Afghanistan 2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                 NaN           NaN         NaN                  NaN
# 1                 NaN           NaN         NaN                  NaN
# 2                 NaN           NaN         NaN                  NaN
# 3                 NaN           NaN         NaN                  NaN
# 4                 NaN           NaN         NaN                  NaN
#
#    total_cases_per_million  new_cases_per_million  \
# 0                     0.03                   0.03
# ...

# %%
groups = data.groupby(['name']).sum()
groups
# Out:
#              total_cases  new_cases  new_cases_smoothed  total_deaths  \
# name
# Afghanistan     1.45e+07    57898.0            57629.85      561122.0
# Albania         1.45e+07   129694.0           129258.57      279466.0
# Algeria         2.27e+07   119805.0           119309.57      701564.0
# Andorra         1.84e+06    12805.0            12712.01       27056.0
# Angola          3.60e+06    24518.0            24115.29       90652.0
# ...                  ...        ...                 ...           ...
# Venezuela       2.76e+07   184595.0           180661.43      255171.0
# Vietnam         4.59e+05     2791.0             2760.58        8723.0
# Yemen           7.05e+05     5858.0             5699.42      187340.0
# Zambia          9.80e+06    90942.0            90654.57      155693.0
# Zimbabwe        4.95e+06    37859.0            37564.43      174222.0
#
#              new_deaths  new_deaths_smoothed  total_cases_per_million  \
# name
# ...

# %%
filepath2 = "world_dev_ind.csv"
pd.set_option("display.max.columns", None)
pd.set_option("display.precision", 2)

# %%
df2 = pd.read_csv(filepath2)
df2 = df2.rename(columns = {'2016 [YR2016]' : '2016', 
                            '2017 [YR2017]' : '2017',
                            '2018 [YR2018]' : '2018',
                            '2019 [YR2019]' : '2019',
                            '2020 [YR2020]' : '2020'})

df2 = df2.dropna()
df2.tail()
# Out:
#        Country Name Country Code  \
# 378835        World          WLD
# 378836        World          WLD
# 378837        World          WLD
# 378838        World          WLD
# 378839        World          WLD
#
#                                               Series Name        Series Code  \
# 378835  Women who believe a husband is justified in be...     SG.VAW.REFU.ZS
# 378836  Women who were first married by age 15 (% of w...  SP.M15.2024.FE.ZS
# 378837  Women who were first married by age 18 (% of w...  SP.M18.2024.FE.ZS
# 378838  Women's share of population ages 15+ living wi...  SH.DYN.AIDS.FE.ZS
# 378839  Young people (ages 15-24) newly infected with HIV     SH.HIV.INCD.YG
#
#           2016    2017    2018    2019 2020
# 378835      ..      ..      ..      ..   ..
# 378836      ..      ..      ..      ..   ..
# 378837      ..      ..      ..      ..   ..
# 378838    52.9      53      53      53   ..
# 378839  540000  510000  480000  460000   ..

# %%
df2['2016'] = pd.to_numeric(df2['2016'], errors='coerce')
df2['2017'] = pd.to_numeric(df2['2017'], errors='coerce')
df2['2018'] = pd.to_numeric(df2['2018'], errors='coerce')
df2['2019'] = pd.to_numeric(df2['2019'], errors='coerce')
df2['2020'] = pd.to_numeric(df2['2020'], errors='coerce')
df2 = df2.dropna(axis=1, how='all')


wivesdf = df2[
            (df2['Series Code'] == 'NY.GDP.MKTP.CD')]
wivesdf
# Out:
#                                       Country Name Country Code  \
# 466                                    Afghanistan          AFG
# 1901                                       Albania          ALB
# 3336                                       Algeria          DZA
# 4771                                American Samoa          ASM
# 6206                                       Andorra          AND
# ...                                            ...          ...
# 372131                          Sub-Saharan Africa          SSF
# 373566  Sub-Saharan Africa (excluding high income)          SSA
# 375001   Sub-Saharan Africa (IDA & IBRD countries)          TSS
# 376436                         Upper middle income          UMC
# 377871                                       World          WLD
#
#               Series Name     Series Code      2016      2017      2018  \
# 466     GDP (current US$)  NY.GDP.MKTP.CD  1.80e+10  1.89e+10  1.84e+10
# ...
